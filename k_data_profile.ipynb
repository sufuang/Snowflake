# %% [markdown]
# # Data profiling
#   - Module Name: k_data_profile.py
#   - Purpose: Create Data profiling reports for exploratory Data Analysis
#   - Created data: Jan, 2020
#   -Author: Sophia Yue
#
# ## Functionality:
#     1.Connect Python to Snowflake with URL = 'abs_itds_dev.east-us-2.azure'
#     2.Retrieve all the tables in EDM_CONFIRMED_DEV.DW_C_PRODUCT
#     3.Ignore table with suffix of _COPY, _TEST, _TMP, _WRK, _FlAT, _TEMP
#     4.Retrieve data from the tables in step2 and feed the data to profile_report and save the report to a html file
#     5.Provide error handling
#
# ## Instruction:
#  - Base on your need to change the values of  the dictionary including credential information
#    -  Use Safeway username and password for LDAP
#  - You can run the code via Spyder, Jupyter, 'python k_get_cnt.py' from command line
#  - Provide the capability to handle specific table(s) or batch to get all the tables
#    - For batch mode, from "Enter table name(s")command line,hit 'enter'
#      Otherwise, enter the table name(s) and seperate by ','
#  - Provide the capability to enter the path name for report files
#    - Hit enter for default path
#
# ## Notes:
#     - Install snowflake-connector-python
#       - pip install --upgrade snowflake-connector-python
#     - All the common codes are in OneDrive

# %% [markdown]
# ## Step 1: Get common codes
#  -  Get elapse time
#  -  Get common python functions for Snowflake
# ## Step 2: Connect Python to Snowflake
#  - Define dictionary for connect setting
#  - Invoke cf_sf_connect to set connection

# %%
import pandas as pd
import pandas_profiling
import datetime
from datetime import datetime, timedelta, date
import time 
import snowflake.connector
import os
from os import path
import logging



""" 
Step 1: Get common codes 
"""
prg_name = ""
path_code = "C:\\Users\\syue003\\wip_RecSys\\"
c_timedte = path_code + "c_time_dte.py" 
exec(compile(open(c_timedte, 'rb').read(),c_timedte, 'exec'))
"""Get common functions to connect Python to Snowflake """
c_sf_com_fnc =  path_code + "c_sf_com_fnc.py"

exec(compile(open(c_sf_com_fnc, 'rb').read(),c_sf_com_fnc, 'exec'))

""" 
Step 2: Connect Python to Snowflake
 - Define dictionary for connect setting
 - Invoke cf_sf_connect to set connection 

"""
d_secrets = {
    "account"   : "abs_itds_dev.east-us-2.azure",
    "role"      : "EDDM_DATA_READER_GG", 
    "user"      : "syue003@safeway.com",
    "warehouse" : "LOAD_WH",            
    "database"  : "EDM_CONFIRMED_DEV",
    "schema"    : "DW_C_PRODUCT",
    "password"  : "Chungli$1"
    
  }

db_nm  = d_secrets["database"]
sch_nm = d_secrets["schema"]


connection = cf_sf_connect (d_secrets)
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...

# %% [markdown]
# ## Step 3: Enter Table name(s)
#   - If table name is not ''
#     - Will strip leading and trailing spaces and convert table name to upper case
#   - If table name is '', will use batch mode
#     - Build a list to get table names under database EDM_CONFIRMED_DEV with schema  DW_C_PRODUCT
#       - Ignore table with suffix  of  _COPY, _TEST, _TMP, _WRK, _FLAT,  _TEMP, or _TST

# %%
l_tbl_nm  = list(map(str, input("Hit 'Enter' for batch mode or enter table name(s)and use ',' as a seperator: ").split(','))) 
l_tbl_nm = [tbl_nm.upper().strip()  for tbl_nm in l_tbl_nm ] 

if l_tbl_nm [0] == '':
    q_tbl_nm = f"""SELECT table_name  FROM {db_nm}.INFORMATION_SCHEMA.COLUMNS 
    WHERE TABLE_SCHEMA = '{sch_nm}' 
      and  table_name not like '%_COPY'  and  table_name not like  '%_TEST' 
      and  table_name not like '%_TMP'   and  table_name not like  '%_WRK%'
      and  table_name not like '%_FLAT'  and  table_name not like  '%_TEMP'
      and  table_name not like '%_TST'
      group by table_name order by table_name"""
 
    df_q_tbl_nm = cf_cr_df_cur_qry(q_tbl_nm)
    
    """ 
    - Create a dataframe from the q_tbl_nm qyery result 
    - Create a list of tbl_nm and flatten the list
    """
    df_q_tbl_nm = cf_cr_df_cur_qry(q_tbl_nm)
    l_tbl_1 =  df_q_tbl_nm.values.tolist() # list with list: [['BANNER'], ['BOD_LAST_RUN_STATUS'], ...., ['ZZ_TST_ECAT']]
    l_tbl_nm = [item for sublist in l_tbl_1 for item in sublist] # list: ['BANNER', 'BOD_LAST_RUN_STATUS', ...., 'ZZ_TST_ECAT']
# Out:
# Hit 'Enter' for batch mode or enter table name(s)and use ',' as a seperator:

# %% [markdown]
# ## Step 4: Enter path for output
#     If path name is '', will use default path
#     otherwise, will create a folder if folder does not exist

# %%
output_path = str(input("Hit 'Enter' for default path or enter the path name: ")).strip()
if output_path == '':
    output_path = 'C:\\SYUE\\EDM\\Data_profiling_report\\'
else:
  if not os.path.exists(output_path):
     os.mkdir(output_path)
# Out:
# Hit 'Enter' for default path or enter the path name: C:\\SYUE\\EDM\\Data_profiling_rpt\\

# %% [markdown]
#
# ## Step 5: Build a dictionary to save count from all the tables been selected
# - If the table does not exist, will cause ProgrammingError
#   - To use 'except ProgrammingError:'
#     - Need to import ProgrammingError from pyobdc
#       - from pyodbc import ProgrammingError
#     - The system still prints system error message
#   - Use generic error message instead
#     -  except Exception
#     -  logging.exception

# %%
cnt_lmt_x = 20
cnt_lmt_y = 100000 

d_tbl_cnt = {}
i = 0
for tbl_nm in l_tbl_nm:  
    try:
       i += 1 
       q_cnt= f"select count(*) from {db_nm}.{sch_nm}.{tbl_nm}"
       cur_q_cnt  = connection.cursor().execute(q_cnt)  
       for row in cur_q_cnt:
           cnt = row[0]
           if cnt >  cnt_lmt_x:
              d_tbl_cnt[tbl_nm] = cnt      
    except Exception:
          logging.exception(f'table {db_nm}.{sch_nm}.{tbl_nm} cause an error')

# %% [markdown]
#
# ## Step 6: Create profile reports
#  - Will base on count of table and cnt_lmt_y to get smp_pct to sample the rows for creating profile report
#  - Table CONSUMER_WARNING will cause integer converting to floating overflow error
#    - Will exclude the table
#  -  For a table with count > 1,000,000, it'd take more than 2 hours to complete the profile report

# %%
if len(d_tbl_cnt) == 0:
    print ('No table is required to create profiling report.')
else:    
  for tbl_nm, cnt in d_tbl_cnt.items():
      print ('tbl_name', tbl_nm, 'cnt', cnt, 'cnt_lmt_y', cnt_lmt_y  )
      smp_pct = 100.00
      try:
        if cnt >  cnt_lmt_y :
             print('big') 
             smp_pct = round(cnt_lmt_y/cnt * 100, 0) 
        print(f'table_name: {tbl_nm}, smp_pct = {smp_pct}')
        s_col = cf_get_col_nm(tbl_nm)
        if len(s_col) == 0:
           print(f"No column been selected for table  '{tbl_nm}' and not required to create a profiling report. ")
           continue
        
        q_sel_data = f'select {s_col}  from {db_nm}.{sch_nm}.{tbl_nm} tablesample bernoulli ({smp_pct})'
        file_nm_low = tbl_nm.lower()
        int_smp_pct = int(smp_pct)
        file_nm = f'{tbl_nm}_{int_smp_pct}pct.html'
        df_q_sel_data = cf_cr_df_cur_qry(q_sel_data) 
        cf_cr_data_profile_rpt(df_q_sel_data, file_nm)
      except Exception as ex:
          logging.exception(f'table {db_nm}.{sch_nm}.{tbl_nm} cause an error')
# Out:
# tbl_name BUYER cnt 486 cnt_lmt_y 100000
# table_name: BUYER, smp_pct = 100.0
# process table:BUYER_100pct.html
#  Pandas Profiling Report for BUYER_100pct.html.
#  It took 10.636000 seconds - 0hh:0mm:10ss.
#  start time: Feb 24 2020 15:56:46  end time:  Feb 24 2020 15:56:56
# tbl_name CONSUMER_WARNING cnt 374 cnt_lmt_y 100000
# table_name: CONSUMER_WARNING, smp_pct = 100.0
# process table:CONSUMER_WARNING_100pct.html
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\model\correlations.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
#  Pandas Profiling Report for CONSUMER_WARNING_100pct.html.
#  It took 13.697000 seconds - 0hh:0mm:13ss.
#  start time: Feb 24 2020 15:56:58  end time:  Feb 24 2020 15:57:12
# tbl_name CONSUMER_WARNING_SOURCE cnt 425 cnt_lmt_y 100000
# table_name: CONSUMER_WARNING_SOURCE, smp_pct = 100.0
# process table:CONSUMER_WARNING_SOURCE_100pct.html
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\model\correlations.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
#  Pandas Profiling Report for CONSUMER_WARNING_SOURCE_100pct.html.
#  It took 14.105000 seconds - 0hh:0mm:14ss.
#  start time: Feb 24 2020 15:57:14  end time:  Feb 24 2020 15:57:28
# tbl_name CORPORATE_ITEM cnt 514063 cnt_lmt_y 100000
# big
# table_name: CORPORATE_ITEM, smp_pct = 19.0
# process table:CORPORATE_ITEM_19pct.html
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\model\correlations.py:126: UserWarning: There was an attempt to calculate the cramers correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"cramers": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'not enough values to unpack (expected 2, got 1)')
#   correlation_name=correlation_name, error=error
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\model\correlations.py:126: UserWarning: There was an attempt to calculate the recoded correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"recoded": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'diag requires an array of at least two dimensions')
#   correlation_name=correlation_name, error=error
#  Pandas Profiling Report for CORPORATE_ITEM_19pct.html.
#  It took 672.204000 seconds - 0hh:11mm:12ss.
#  start time: Feb 24 2020 15:57:42  end time:  Feb 24 2020 16:08:55
# tbl_name CORPORATE_ITEM_UPC_REFERENCE cnt 689059 cnt_lmt_y 100000
# big
# table_name: CORPORATE_ITEM_UPC_REFERENCE, smp_pct = 15.0
# process table:CORPORATE_ITEM_UPC_REFERENCE_15pct.html
#  Pandas Profiling Report for CORPORATE_ITEM_UPC_REFERENCE_15pct.html.
#  It took 325.776000 seconds - 0hh:5mm:25ss.
#  start time: Feb 24 2020 16:09:05  end time:  Feb 24 2020 16:14:31
# tbl_name CORPORATE_ITEM_UPC_ROG_REFERENCE cnt 2763002 cnt_lmt_y 100000
# big
# table_name: CORPORATE_ITEM_UPC_ROG_REFERENCE, smp_pct = 4.0
# process table:CORPORATE_ITEM_UPC_ROG_REFERENCE_4pct.html
#  Pandas Profiling Report for CORPORATE_ITEM_UPC_ROG_REFERENCE_4pct.html.
#  It took 416.648000 seconds - 0hh:6mm:56ss.
#  start time: Feb 24 2020 16:14:44  end time:  Feb 24 2020 16:21:41
# tbl_name CORPORATE_ITEM_UPC_ROG_RETAIL cnt 635154 cnt_lmt_y 100000
# big
# table_name: CORPORATE_ITEM_UPC_ROG_RETAIL, smp_pct = 16.0
# process table:CORPORATE_ITEM_UPC_ROG_RETAIL_16pct.html
#  Pandas Profiling Report for CORPORATE_ITEM_UPC_ROG_RETAIL_16pct.html.
#  It took 204.255000 seconds - 0hh:3mm:24ss.
#  start time: Feb 24 2020 16:21:47  end time:  Feb 24 2020 16:25:12
# tbl_name CURRENT_RETAIL_ITEM_PRICE cnt 7386589 cnt_lmt_y 100000
# big
# table_name: CURRENT_RETAIL_ITEM_PRICE, smp_pct = 1.0
# process table:CURRENT_RETAIL_ITEM_PRICE_1pct.html
#  Pandas Profiling Report for CURRENT_RETAIL_ITEM_PRICE_1pct.html.
#  It took 258.211993 seconds - 0hh:4mm:18ss.
#  start time: Feb 24 2020 16:25:25  end time:  Feb 24 2020 16:29:44
# tbl_name DEPARTMENT cnt 23 cnt_lmt_y 100000
# table_name: DEPARTMENT, smp_pct = 100.0
# process table:DEPARTMENT_100pct.html
#  Pandas Profiling Report for DEPARTMENT_100pct.html.
#  It took 7.290271 seconds - 0hh:0mm:7ss.
#  start time: Feb 24 2020 16:29:47  end time:  Feb 24 2020 16:29:54
# tbl_name ECATALOG_ITEM_NEW_IMG cnt 485144 cnt_lmt_y 100000
# big
# table_name: ECATALOG_ITEM_NEW_IMG, smp_pct = 21.0
# process table:ECATALOG_ITEM_NEW_IMG_21pct.html
#  Pandas Profiling Report for ECATALOG_ITEM_NEW_IMG_21pct.html.
#  It took 235.094857 seconds - 0hh:3mm:55ss.
#  start time: Feb 24 2020 16:30:02  end time:  Feb 24 2020 16:33:57
# tbl_name FACILITY cnt 54 cnt_lmt_y 100000
# table_name: FACILITY, smp_pct = 100.0
# process table:FACILITY_100pct.html
#  Pandas Profiling Report for FACILITY_100pct.html.
#  It took 12.890000 seconds - 0hh:0mm:12ss.
#  start time: Feb 24 2020 16:34:00  end time:  Feb 24 2020 16:34:13
# tbl_name FACILITY_DEPARTMENT cnt 765 cnt_lmt_y 100000
# table_name: FACILITY_DEPARTMENT, smp_pct = 100.0
# process table:FACILITY_DEPARTMENT_100pct.html
#  Pandas Profiling Report for FACILITY_DEPARTMENT_100pct.html.
#  It took 11.886000 seconds - 0hh:0mm:11ss.
#  start time: Feb 24 2020 16:34:18  end time:  Feb 24 2020 16:34:30
# tbl_name FACILITY_DEPARTMENT_SECTION cnt 1853 cnt_lmt_y 100000
# table_name: FACILITY_DEPARTMENT_SECTION, smp_pct = 100.0
# process table:FACILITY_DEPARTMENT_SECTION_100pct.html
#  Pandas Profiling Report for FACILITY_DEPARTMENT_SECTION_100pct.html.
#  It took 10.792000 seconds - 0hh:0mm:10ss.
#  start time: Feb 24 2020 16:34:35  end time:  Feb 24 2020 16:34:46
# tbl_name ITEM_RECODE cnt 28034 cnt_lmt_y 100000
# table_name: ITEM_RECODE, smp_pct = 100.0
# process table:ITEM_RECODE_100pct.html
#  Pandas Profiling Report for ITEM_RECODE_100pct.html.
#  It took 39.454000 seconds - 0hh:0mm:39ss.
#  start time: Feb 24 2020 16:34:51  end time:  Feb 24 2020 16:35:30
# tbl_name KAFKAOUTQUEUE cnt 692071 cnt_lmt_y 100000
# big
# table_name: KAFKAOUTQUEUE, smp_pct = 14.0
# process table:KAFKAOUTQUEUE_14pct.html
#  Pandas Profiling Report for KAFKAOUTQUEUE_14pct.html.
#  It took 161.863000 seconds - 0hh:2mm:41ss.
#  start time: Feb 24 2020 16:35:37  end time:  Feb 24 2020 16:38:19
# tbl_name OPERATING_AREA cnt 35 cnt_lmt_y 100000
# table_name: OPERATING_AREA, smp_pct = 100.0
# process table:OPERATING_AREA_100pct.html
#  Pandas Profiling Report for OPERATING_AREA_100pct.html.
#  It took 10.050000 seconds - 0hh:0mm:10ss.
#  start time: Feb 24 2020 16:38:23  end time:  Feb 24 2020 16:38:33
# tbl_name PENDING_RETAIL_ITEM_PRICE cnt 7530727 cnt_lmt_y 100000
# big
# table_name: PENDING_RETAIL_ITEM_PRICE, smp_pct = 1.0
# process table:PENDING_RETAIL_ITEM_PRICE_1pct.html
#  Pandas Profiling Report for PENDING_RETAIL_ITEM_PRICE_1pct.html.
#  It took 305.763000 seconds - 0hh:5mm:5ss.
#  start time: Feb 24 2020 16:38:40  end time:  Feb 24 2020 16:43:46
# tbl_name PRICE_AREA cnt 97 cnt_lmt_y 100000
# table_name: PRICE_AREA, smp_pct = 100.0
# process table:PRICE_AREA_100pct.html
#  Pandas Profiling Report for PRICE_AREA_100pct.html.
#  It took 5.856000 seconds - 0hh:0mm:5ss.
#  start time: Feb 24 2020 16:43:50  end time:  Feb 24 2020 16:43:56
# tbl_name PRODUCTION_CATEGORY cnt 470 cnt_lmt_y 100000
# table_name: PRODUCTION_CATEGORY, smp_pct = 100.0
# process table:PRODUCTION_CATEGORY_100pct.html
#  Pandas Profiling Report for PRODUCTION_CATEGORY_100pct.html.
#  It took 9.496000 seconds - 0hh:0mm:9ss.
#  start time: Feb 24 2020 16:43:59  end time:  Feb 24 2020 16:44:08
# tbl_name PRODUCTION_CLASS cnt 1423 cnt_lmt_y 100000
# table_name: PRODUCTION_CLASS, smp_pct = 100.0
# process table:PRODUCTION_CLASS_100pct.html
#  Pandas Profiling Report for PRODUCTION_CLASS_100pct.html.
#  It took 11.274000 seconds - 0hh:0mm:11ss.
#  start time: Feb 24 2020 16:44:10  end time:  Feb 24 2020 16:44:22
# tbl_name PRODUCTION_GROUP cnt 71 cnt_lmt_y 100000
# table_name: PRODUCTION_GROUP, smp_pct = 100.0
# process table:PRODUCTION_GROUP_100pct.html
#  Pandas Profiling Report for PRODUCTION_GROUP_100pct.html.
#  It took 6.948000 seconds - 0hh:0mm:6ss.
#  start time: Feb 24 2020 16:44:24  end time:  Feb 24 2020 16:44:31
# tbl_name PRODUCTION_SUB_CLASS cnt 1467 cnt_lmt_y 100000
# table_name: PRODUCTION_SUB_CLASS, smp_pct = 100.0
# process table:PRODUCTION_SUB_CLASS_100pct.html
#  Pandas Profiling Report for PRODUCTION_SUB_CLASS_100pct.html.
#  It took 10.915000 seconds - 0hh:0mm:10ss.
#  start time: Feb 24 2020 16:44:33  end time:  Feb 24 2020 16:44:43
# tbl_name PRODUCTION_SUB_SUB_CLASS cnt 1481 cnt_lmt_y 100000
# table_name: PRODUCTION_SUB_SUB_CLASS, smp_pct = 100.0
# process table:PRODUCTION_SUB_SUB_CLASS_100pct.html
#  Pandas Profiling Report for PRODUCTION_SUB_SUB_CLASS_100pct.html.
#  It took 11.566000 seconds - 0hh:0mm:11ss.
#  start time: Feb 24 2020 16:44:45  end time:  Feb 24 2020 16:44:57
# tbl_name PROMOTION_RETAIL_ORDER_GROUP cnt 136995 cnt_lmt_y 100000
# big
# table_name: PROMOTION_RETAIL_ORDER_GROUP, smp_pct = 73.0
# process table:PROMOTION_RETAIL_ORDER_GROUP_73pct.html
#  Pandas Profiling Report for PROMOTION_RETAIL_ORDER_GROUP_73pct.html.
#  It took 341.704000 seconds - 0hh:5mm:41ss.
#  start time: Feb 24 2020 16:45:08  end time:  Feb 24 2020 16:50:49
# tbl_name PROMOTION_STORE cnt 5010706 cnt_lmt_y 100000
# big
# table_name: PROMOTION_STORE, smp_pct = 2.0
# process table:PROMOTION_STORE_2pct.html
#  Pandas Profiling Report for PROMOTION_STORE_2pct.html.
#  It took 105.361000 seconds - 0hh:1mm:45ss.
#  start time: Feb 24 2020 16:50:59  end time:  Feb 24 2020 16:52:45
# tbl_name PROMOTION_UPC_PRICE_AREA cnt 398 cnt_lmt_y 100000
# table_name: PROMOTION_UPC_PRICE_AREA, smp_pct = 100.0
# process table:PROMOTION_UPC_PRICE_AREA_100pct.html
#  Pandas Profiling Report for PROMOTION_UPC_PRICE_AREA_100pct.html.
#  It took 20.376000 seconds - 0hh:0mm:20ss.
#  start time: Feb 24 2020 16:52:48  end time:  Feb 24 2020 16:53:08
# tbl_name PROMOTION_VENDOR cnt 66834 cnt_lmt_y 100000
# table_name: PROMOTION_VENDOR, smp_pct = 100.0
# process table:PROMOTION_VENDOR_100pct.html
#  Pandas Profiling Report for PROMOTION_VENDOR_100pct.html.
#  It took 27.821000 seconds - 0hh:0mm:27ss.
#  start time: Feb 24 2020 16:53:33  end time:  Feb 24 2020 16:54:01
# tbl_name RETAIL_ORDER_GROUP_UPC cnt 726175 cnt_lmt_y 100000
# big
# table_name: RETAIL_ORDER_GROUP_UPC, smp_pct = 14.0
# process table:RETAIL_ORDER_GROUP_UPC_14pct.html
#  Pandas Profiling Report for RETAIL_ORDER_GROUP_UPC_14pct.html.
#  It took 627.970000 seconds - 0hh:10mm:27ss.
#  start time: Feb 24 2020 16:54:22  end time:  Feb 24 2020 17:04:50
# tbl_name RETAIL_STORE_UPC cnt 1545754 cnt_lmt_y 100000
# big
# table_name: RETAIL_STORE_UPC, smp_pct = 6.0
# process table:RETAIL_STORE_UPC_6pct.html
#  Pandas Profiling Report for RETAIL_STORE_UPC_6pct.html.
#  It took 112.088000 seconds - 0hh:1mm:52ss.
#  start time: Feb 24 2020 17:04:57  end time:  Feb 24 2020 17:06:49
# tbl_name SECTION cnt 43 cnt_lmt_y 100000
# table_name: SECTION, smp_pct = 100.0
# process table:SECTION_100pct.html
#  Pandas Profiling Report for SECTION_100pct.html.
#  It took 6.321000 seconds - 0hh:0mm:6ss.
#  start time: Feb 24 2020 17:06:51  end time:  Feb 24 2020 17:06:58
# tbl_name SMIC_CATEGORY cnt 865 cnt_lmt_y 100000
# table_name: SMIC_CATEGORY, smp_pct = 100.0
# process table:SMIC_CATEGORY_100pct.html
#  Pandas Profiling Report for SMIC_CATEGORY_100pct.html.
#  It took 8.758000 seconds - 0hh:0mm:8ss.
#  start time: Feb 24 2020 17:07:00  end time:  Feb 24 2020 17:07:09
# tbl_name SMIC_CLASS cnt 3513 cnt_lmt_y 100000
# table_name: SMIC_CLASS, smp_pct = 100.0
# process table:SMIC_CLASS_100pct.html
#  Pandas Profiling Report for SMIC_CLASS_100pct.html.
#  It took 11.163000 seconds - 0hh:0mm:11ss.
#  start time: Feb 24 2020 17:07:11  end time:  Feb 24 2020 17:07:22
# tbl_name SMIC_GROUP cnt 94 cnt_lmt_y 100000
# table_name: SMIC_GROUP, smp_pct = 100.0
# process table:SMIC_GROUP_100pct.html
#  Pandas Profiling Report for SMIC_GROUP_100pct.html.
#  It took 8.954000 seconds - 0hh:0mm:8ss.
#  start time: Feb 24 2020 17:07:24  end time:  Feb 24 2020 17:07:33
# tbl_name SMIC_SUB_CLASS cnt 8262 cnt_lmt_y 100000
# table_name: SMIC_SUB_CLASS, smp_pct = 100.0
# process table:SMIC_SUB_CLASS_100pct.html
#  Pandas Profiling Report for SMIC_SUB_CLASS_100pct.html.
#  It took 9.438000 seconds - 0hh:0mm:9ss.
#  start time: Feb 24 2020 17:07:37  end time:  Feb 24 2020 17:07:46
# tbl_name SMIC_SUB_SUB_CLASS cnt 12232 cnt_lmt_y 100000
# table_name: SMIC_SUB_SUB_CLASS, smp_pct = 100.0
# process table:SMIC_SUB_SUB_CLASS_100pct.html
#  Pandas Profiling Report for SMIC_SUB_SUB_CLASS_100pct.html.
#  It took 10.415000 seconds - 0hh:0mm:10ss.
#  start time: Feb 24 2020 17:07:49  end time:  Feb 24 2020 17:07:59
# tbl_name STORE_RETAIL_ITEM_PRICE cnt 27478 cnt_lmt_y 100000
# table_name: STORE_RETAIL_ITEM_PRICE, smp_pct = 100.0
# process table:STORE_RETAIL_ITEM_PRICE_100pct.html
#  Pandas Profiling Report for STORE_RETAIL_ITEM_PRICE_100pct.html.
#  It took 47.435000 seconds - 0hh:0mm:47ss.
#  start time: Feb 24 2020 17:08:04  end time:  Feb 24 2020 17:08:52
# tbl_name SUPPLY_CHAIN_ITEM cnt 1026767 cnt_lmt_y 100000
# big
# table_name: SUPPLY_CHAIN_ITEM, smp_pct = 10.0
# process table:SUPPLY_CHAIN_ITEM_10pct.html
#  Pandas Profiling Report for SUPPLY_CHAIN_ITEM_10pct.html.
#  It took 650.456000 seconds - 0hh:10mm:50ss.
#  start time: Feb 24 2020 17:09:14  end time:  Feb 24 2020 17:20:04
# tbl_name VENDOR_ITEM cnt 1050549 cnt_lmt_y 100000
# big
# table_name: VENDOR_ITEM, smp_pct = 10.0
# process table:VENDOR_ITEM_10pct.html
#  Pandas Profiling Report for VENDOR_ITEM_10pct.html.
#  It took 214.068000 seconds - 0hh:3mm:34ss.
#  start time: Feb 24 2020 17:20:20  end time:  Feb 24 2020 17:23:54
# tbl_name ZZ_TST_ECAT cnt 170005 cnt_lmt_y 100000
# big
# table_name: ZZ_TST_ECAT, smp_pct = 59.0
# process table:ZZ_TST_ECAT_59pct.html
#  Pandas Profiling Report for ZZ_TST_ECAT_59pct.html.
#  It took 407.905000 seconds - 0hh:6mm:47ss.
#  start time: Feb 24 2020 17:24:06  end time:  Feb 24 2020 17:30:54
